# %%
다변량 그래프 그리기-히스토그램

seaborn라이브러리는 matplotlib라이브러리를 기반으로 만든 라이브러리
# Out:
#   File "<ipython-input-1-e81e74ce0325>", line 1
#     다변량 그래프 그리기-히스토그램
#           ^
# SyntaxError: invalid syntax

# %%
import seaborn as sns
tips=sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
seaborn라이브러리로 히스토그램
seaborm 라이브러리로 히스토그램을 그리려면 subplots,distplot 메서드를 사용
distplot메서드:기본틀 만들 total_bill메서드 :total_bill열데이터를 전달

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
ax=plt.subplots()
ax=sns.distplot(tips["total_bill"])
ax.set_title("total bill histogram with density plot")
# Out:
# C:\Users\A\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# Text(0.5,1,'total bill histogram with density plot')

# %%
ax=plt.subplots()
ax=sns.distplot(tips["total_bill"],kde=False)
ax.set_title("Total Bill Histogram")
ax.set_xlabel("Total Bill")
ax.set_ylabel("Frequency")
# Out:
# C:\Users\A\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# Text(0,0.5,'Frequency')

# %%
ax=plt.subplots()
ax=sns.distplot(tips["total_bill"],hist=False)
ax.set_title("Total Bill Histogram")
ax.set_xlabel("Total Bill")
ax.set_ylabel("Unit Probability")
# Out:
# C:\Users\A\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# Text(0,0.5,'Frequency')

# %%
ax=plt.subplots()
ax=sns.distplot(tips["total_bill"],rug=True)
ax.set_title("total bill histogram with density plot")
ax.set_xlabel("Total Bill")
# Out:
# C:\Users\A\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# Text(0.5,0,'Total Bill')

# %%
count그래프 이산값을 나타낸 그래프

# %%
ax=plt.subplots()
ax=sns.countplot("day",data=tips)
ax.set_title("Count of days")
ax.set_xlabel("Day of the Week")
ax.set_ylabel("Frequency")
# Out:
# Text(0,0.5,'Frequency')

# %%
다양한 종류의 이변량 그래프 그리기
seadorn라이브러리로 산점도 그리기
regplot메서드를 사용하면 산점도 그래프와 회귀선을 그릴수 있다

# %%
ax=plt.subplots()
ax=sns.regplot(x="total_bill",y="tip",data=tips)
ax.set_title("Scatterplot of Total Bill and Tip")
ax.set_xlabel("Total Bill")
ax.set_ylabel("Tip")
# Out:
# C:\Users\A\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# Text(0,0.5,'Tip')

# %%
ax=plt.subplots()
ax=sns.regplot(x="total_bill",y="tip",data=tips,fit_reg=False)
ax.set_title("Scatterplot of Total Bill and Tip")
ax.set_xlabel("Total Bill")
ax.set_ylabel("Tip")
# Out:
# Text(0,0.5,'Tip')

# %%
joint=sns.jointplot(x="total_bill",y="tip",data=tips)
joint.set_axis_labels(xlabel="Total Bill",ylabel="Tip")
joint.fig.suptitle("Joint Plot of Total Bill and Tip" )
# Out:
# C:\Users\A\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# Text(0.5,0.98,'Joint Plot of Total Bill and Tip')

# %%
#hexbin 육각 그래프 데이터를 쌓아둔
joint=sns.jointplot(x="total_bill",y="tip",data=tips,kind="hex")
joint.set_axis_labels(xlabel="Total Bill",ylabel="Tip")
joint.fig.suptitle("Joint Plot of Total Bill and Tip" ,fontsize=10,y=1.03)
# Out:
# C:\Users\A\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# Text(0.5,1.03,'Joint Plot of Total Bill and Tip')

# %%
#이차원 밀집도 그리기
ax=plt.subplots()
ax=sns.kdeplot(data=tips["total_bill"],
              data2=tips["tip"],
              shade=True)
ax.set_title("Scatterplot of Total Bill and Tip")
ax.set_xlabel("Total Bill")
ax.set_ylabel("Tip")
# Out:
# C:\Users\A\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# Text(0,0.5,'Tip')

# %%
바그래프 그리기

# %%
ax=plt.subplots()
ax=sns.barplot(x="time",y="total_bill",data=tips)
ax.set_title("Bar plot of average total bill for time of day")
ax.set_xlabel("Time of day")
ax.set_ylabel("Average total bill")
# Out:
# C:\Users\A\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# Text(0,0.5,'Average total bill')

# %%
ax=plt.subplots()
ax=sns.boxplot(x="time",y="total_bill",data=tips)
ax.set_title("Boxplot of total bill by time of day")
ax.set_xlabel("Time of day")
ax.set_ylabel("total_bill")
# Out:
# Text(0,0.5,'total_bill')

# %%
ax=plt.subplots()
ax=sns.violinplot(x="time",y="total_bill",data=tips)
ax.set_title("Violin plot of total bill by time of day")
ax.set_xlabel("Time of day")
ax.set_ylabel("total_bill")
# Out:
# C:\Users\A\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# Text(0,0.5,'total_bill')

# %%
fig=sns.pairplot(tips)

# %%
pair_grid=sns.PairGrid(tips)
pair_grid=pair_grid.map_upper(sns.regplot)
pair_grid=pair_grid.map_lower(sns.kdeplot)
pair_grid=pair_grid.map_diag(sns.distplot,rug=True)
plt.show()
# Out:
# C:\Users\A\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
ax=plt.subplots()
ax=sns.violinplot(x="time",y="total_bill",data=tips,hue="sex",split=True)
plt.show()
# Out:
# C:\Users\A\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
ax=plt.subplots()
ax=sns.violinplot(x="time",y="total_bill",data=tips,hue="sex")
plt.show()
# Out:
# C:\Users\A\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
scatter=sns.lmplot(x="total_bill",y="tip",data=tips,hue="sex",fit_reg=False)
plt.show()

# %%
scatter=sns.lmplot(x="total_bill",y="tip",data=tips,hue="sex",fit_reg=True)
plt.show()
# Out:
# C:\Users\A\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
fig=sns.pairplot(tips,hue="sex")
# Out:
# C:\Users\A\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
산점도 그래프의 크기와 모양 조절하기

# %%
scatter=sns.lmplot(x="total_bill",y="tip",data=tips,hue="sex",fit_reg=False,scatter_kws={"s":tips["size"]*10})
plt.show()

# %%
scatter=sns.lmplot(x="total_bill",y="tip",data=tips,hue="sex",fit_reg=False,markers=["o","x"],scatter_kws={"s":tips["size"]*10})
plt.show()

# %%
lmplot 메서드로 4개의 데이터 그룹에 대한 그래프 한번에 그리기

# %%
anscombe=sns.load_dataset("anscombe")
anscombe_plot=sns.lmplot(x="x",y="y",data=anscombe,fit_reg=False)

# %%
anscombe_plot=sns.lmplot(x="x",y="y",data=anscombe,fit_reg=False,col="dataset",col_wrap=2)
#col_wrap:그래프를 그릴 열의 최대값 지정
#col:데이터 그룹을 구분할 열

# %%
데이터프레임과 시리즈로 그래프 그리기

# %%
#tlflwm rkqtdmf dldydgkdu gltmxh rmfoa rmflrl
ax=plt.subplots()
ax=tips["total_bill"].plot.hist()

# %%
fig,ax=plt.subplots()
ax=tips[["total_bill","tip"]].plot.hist(alpha=0.5,bins=20,ax=ax)
#alpha:투명도 bins:x축의 간격 ax:인수 파라미터

# %%
subplot과 subplots모두 한번에 여러 그래프를 보여주기 위해 사용되는 코드이지만 사용법이 다르다
subplot 의 예
plt.subplot(2,1,1)
plt.subplot(2,1,2)
plt.show()

subplots의 예
fig,axes=plt.subplots(nrow=2,ncol=1)
plt.show()
subplots에선 두개의 값을 받을 수 있는데 figure 와 axes값을 받을 수 있다.

matplotlib,pyplot,subplots는 figure와 axes오브젝트를 반환하는데 
f,ax로 받으면

# %%
ax=plt.subplots()
ax=tips["tip"].plot.kde()

# %%
fig,ax=plt.subplots()
ax=tips.plot.scatter(x="total_bill",y="tip",ax=ax)

# %%
fig,ax=plt.subplots()
ax=tips.plot.hexbin(x="total_bill",y="tip",ax=ax)

# %%
fig,ax=plt.subplots()
ax=tips.plot.hexbin(x="total_bill",y="tip",gridsize=10,ax=ax)

# %%
fig,ax=plt.subplots()
ax=tips.plot.box(ax=ax)

# %% [markdown]
# 그래프에 스타일적용하기

# %%
fig,ax=plt.subplots()
ax=sns.violinplot(x="time",y="total_bill",hue="sex",data=tips,split=True)
# Out:
# C:\Users\A\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.set_style("whitegrid")#배경스타일 지정
fig,ax=plt.subplots()
ax=sns.violinplot(x="time",y="total_bill",hue="sex",data=tips,split=True)
# Out:
# C:\Users\A\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
fig=plt.figure()
seaborn_styles=["darkgrid","whitegrid","dark","white","ticks"]
for idx,style in enumerate(seaborn_styles):
    plot_position=idx+1
    with sns.axes_style(style):
        ax=fig.add_subplot(2,3,plot_position)
        violin=sns.violinplot(x="time",y="total_bill",data=tips,ax=ax)
        violin.set_title(style)
fig.tight_layout()
# Out:
# C:\Users\A\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
#참고하면 좋은사이트
https://matplotlib.org/api/pyplot_api.html
http://seaborn.pydata.org/
https://matplotlib.org/examples/color/named_colors.html
https://matplotlib.org/api/pyplot_api.html#matplotlib.pyplot.pie

# %%
import matplotlib.pyplot as plt

# Pie chart, where the slices will be ordered and plotted counter-clockwise:
labels = 'Frogs', 'Hogs', 'Dogs', 'Logs'
sizes = [15, 30, 45, 10]
explode = (0, 0.1, 0, 0)  # only "explode" the 2nd slice (i.e. 'Hogs')

fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %%
한글폰트깨질때
matplotlib에서 사용하는 기본 글꼴은 영어 전용
한글을 표기하고 싶다면 한글이 되는 폰트로 기본 폰트를 변경해야합니다

# %%
#matplotlib에서 사용하는 기본 글꼴은 영어 전용
#한글을 표기하고 싶다면 한글이 되는 폰트로 기본 폰트를 변경해야합니다
from matplotlib import font_manager,rc
plt.rcParams['axes.unicode_minus']=False
#
#f_path="/Library/Fonts/AppleGothic.ttf"(맥)
f_path="C:/Windows/Fonts/malgun.ttf" #(윈도우)
font_name=font_manager.FontProperties(fname=f_path).get_name()
rc("font",family=font_name)

# %%
import matplotlib.pyplot as plt

# Pie chart, where the slices will be ordered and plotted counter-clockwise:
labels = '개구리', 'Hogs', 'Dogs', 'Logs'
sizes = [15, 30, 45, 10]
explode = (0, 0.1, 0, 0)  # only "explode" the 2nd slice (i.e. 'Hogs')

fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %%
연습문제

# %%
import seaborn as sns
import pandas as pd
t=pd.read_excel("../data/titanic.xls")
t
# Out:
#       pclass  survived                                               name  \
# 0          1         1                      Allen, Miss. Elisabeth Walton
# 1          1         1                     Allison, Master. Hudson Trevor
# 2          1         0                       Allison, Miss. Helen Loraine
# 3          1         0               Allison, Mr. Hudson Joshua Creighton
# 4          1         0    Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 5          1         1                                Anderson, Mr. Harry
# 6          1         1                  Andrews, Miss. Kornelia Theodosia
# 7          1         0                             Andrews, Mr. Thomas Jr
# 8          1         1      Appleton, Mrs. Edward Dale (Charlotte Lamson)
# 9          1         0                            Artagaveytia, Mr. Ramon
# 10         1         0                             Astor, Col. John Jacob
# 11         1         1  Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# ...

# %%
ax=plt.subplots()
ax=t["age"].plot.hist()

# %%
count = Counter(t['sex'])
print(count)
ax=plt.subplots()
ax=sns.countplot("sex",data=t,palette="Set3")
# Out:
# Counter({'male': 843, 'female': 466})

# %%
t_1=t[t["survived"]==0]

# %%
count = Counter(t_1['pclass'])
print(count)
ax=plt.subplots()
ax=sns.countplot("pclass",data=t_1,facecolor=(0, 0, 0, 0),
                   linewidth=5,
                   edgecolor=sns.color_palette("dark", 3))
# Out:
# Counter({3: 528, 2: 158, 1: 123})

# %%
ax=plt.subplots()
ax=sns.countplot("pclass",data=t)

# %%
labels="사망자","생존자"
a=t.groupby(['survived'], as_index=True).count()
print(a["sex"])
plt.pie(a["sex"], labels=labels, shadow=True, startangle=90,autopct='%1.1f%%')
plt.show()
# Out:
# survived
# 0    809
# 1    500
# Name: sex, dtype: int64

# %%
a=t.groupby(['survived'], as_index=True).count()
a["pclass"]
explode = (0, 0.1)
labels="사망자","생존자"
plt.pie(a["pclass"],explode=explode ,labels=labels,autopct='%1.1f%%',colors=["yellow","skyblue"])
my_circle=plt.Circle( (0,0), 0.5, color='white')
p=plt.gcf()
p.gca().add_artist(my_circle)
plt.show()

# %%
t['survived'].value_counts().plot.pie(autopct='%1.1f%%')

# %%
ax=plt.subplots()
ax=sns.countplot("survived",hue="sex",data=t)

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-163-7e6b98db1bab> in <module>()
# ----> 1 from pyecharts import Pie
#       2
#       3 attr = ['A','B','C','D','E','F']
#       4 v1 = [10, 20, 30, 40, 50, 60]
#       5 v2 = [38, 28, 58, 48, 78, 68]
#
# ModuleNotFoundError: No module named 'pyecharts'
