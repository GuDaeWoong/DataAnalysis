# %%
#-*- coding: utf-8 -*-

from tensorflow.keras.datasets import mnist
from tensorflow.keras.layers import Input, Dense, Reshape, Flatten, Dropout
from tensorflow.keras.layers import BatchNormalization, Activation, LeakyReLU, UpSampling2D, Conv2D
from tensorflow.keras.models import Sequential, Model

import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt

#이미지가 저장될 폴더가 없다면 만듭니다.
import os
if not os.path.exists("./gan_images"):
    os.makedirs("./gan_images")

np.random.seed(3)
tf.random.set_seed(3)

#생성자 모델을 만듭니다.
generator = Sequential()
generator.add(Dense(128*7*7, input_dim=100, activation=LeakyReLU(0.2)))
generator.add(BatchNormalization())
generator.add(Reshape((7, 7, 128)))
generator.add(UpSampling2D())
generator.add(Conv2D(64, kernel_size=5, padding='same'))
generator.add(BatchNormalization())
generator.add(Activation(LeakyReLU(0.2)))
generator.add(UpSampling2D())
generator.add(Conv2D(1, kernel_size=5, padding='same', activation='tanh'))

#판별자 모델을 만듭니다.
discriminator = Sequential()
discriminator.add(Conv2D(64, kernel_size=5, strides=2, input_shape=(28,28,1), padding="same"))
discriminator.add(Activation(LeakyReLU(0.2)))
discriminator.add(Dropout(0.3))
discriminator.add(Conv2D(128, kernel_size=5, strides=2, padding="same"))
discriminator.add(Activation(LeakyReLU(0.2)))
discriminator.add(Dropout(0.3))
discriminator.add(Flatten())
discriminator.add(Dense(1, activation='sigmoid'))
discriminator.compile(loss='binary_crossentropy', optimizer='adam')
discriminator.trainable = False

#생성자와 판별자 모델을 연결시키는 gan 모델을 만듭니다.
ginput = Input(shape=(100,))
dis_output = discriminator(generator(ginput))
gan = Model(ginput, dis_output)
gan.compile(loss='binary_crossentropy', optimizer='adam')
gan.summary()

#신경망을 실행시키는 함수를 만듭니다.
def gan_train(epoch, batch_size, saving_interval):

  # MNIST 데이터 불러오기

  (X_train, _), (_, _) = mnist.load_data()  # 앞서 불러온 적 있는 MNIST를 다시 이용합니다. 단, 테스트과정은 필요없고 이미지만 사용할 것이기 때문에 X_train만 불러왔습니다.
  X_train = X_train.reshape(X_train.shape[0], 28, 28, 1).astype('float32')
  X_train = (X_train - 127.5) / 127.5  # 픽셀값은 0에서 255사이의 값입니다. 이전에 255로 나누어 줄때는 이를 0~1사이의 값으로 바꾸었던 것인데, 여기서는 127.5를 빼준 뒤 127.5로 나누어 줌으로 인해 -1에서 1사이의 값으로 바뀌게 됩니다.
  #X_train.shape, Y_train.shape, X_test.shape, Y_test.shape

  true = np.ones((batch_size, 1))
  fake = np.zeros((batch_size, 1))

  for i in range(epoch):
          # 실제 데이터를 판별자에 입력하는 부분입니다.
          idx = np.random.randint(0, X_train.shape[0], batch_size)
          imgs = X_train[idx]
          d_loss_real = discriminator.train_on_batch(imgs, true)

          #가상 이미지를 판별자에 입력하는 부분입니다.
          noise = np.random.normal(0, 1, (batch_size, 100))
          gen_imgs = generator.predict(noise)
          d_loss_fake = discriminator.train_on_batch(gen_imgs, fake)

          #판별자와 생성자의 오차를 계산합니다.
          d_loss = 0.5 * np.add(d_loss_real, d_loss_fake)
          g_loss = gan.train_on_batch(noise, true)

          print('epoch:%d' % i, ' d_loss:%.4f' % d_loss, ' g_loss:%.4f' % g_loss)

        # 이부분은 중간 과정을 이미지로 저장해 주는 부분입니다. 본 장의 주요 내용과 관련이 없어
        # 소스코드만 첨부합니다. 만들어진 이미지들은 gan_images 폴더에 저장됩니다.
          if i % saving_interval == 0:
              #r, c = 5, 5
              noise = np.random.normal(0, 1, (25, 100))
              gen_imgs = generator.predict(noise)

              # Rescale images 0 - 1
              gen_imgs = 0.5 * gen_imgs + 0.5

              fig, axs = plt.subplots(5, 5)
              count = 0
              for j in range(5):
                  for k in range(5):
                      axs[j, k].imshow(gen_imgs[count, :, :, 0], cmap='gray')
                      axs[j, k].axis('off')
                      count += 1
              fig.savefig("gan_images/gan_mnist_%d.png" % i)

gan_train(4001, 32, 200)  #4000번 반복되고(+1을 해 주는 것에 주의), 배치 사이즈는 32,  200번 마다 결과가 저장되게 하였습니다.
# Out:
# In C:\Users\A\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The text.latex.unicode rcparam was deprecated in Matplotlib 3.0 and will be removed in 3.2.
# In C:\Users\A\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The savefig.frameon rcparam was deprecated in Matplotlib 3.1 and will be removed in 3.3.
# In C:\Users\A\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The pgf.debug rcparam was deprecated in Matplotlib 3.0 and will be removed in 3.2.
# In C:\Users\A\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The verbose.level rcparam was deprecated in Matplotlib 3.1 and will be removed in 3.3.
# In C:\Users\A\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The verbose.fileo rcparam was deprecated in Matplotlib 3.1 and will be removed in 3.3.
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 100)]             0
# _________________________________________________________________
# sequential (Sequential)      (None, 28, 28, 1)         865281
# _________________________________________________________________
# sequential_1 (Sequential)    (None, 1)                 212865
# =================================================================
# Total params: 1,078,146
# Trainable params: 852,609
# Non-trainable params: 225,537
# _________________________________________________________________
# epoch:0  d_loss:0.7053  g_loss:0.6912
# epoch:1  d_loss:0.4624  g_loss:0.3282
# epoch:2  d_loss:0.5686  g_loss:0.1025
# epoch:3  d_loss:0.6585  g_loss:0.0836
# epoch:4  d_loss:0.5769  g_loss:0.1651
# epoch:5  d_loss:0.5088  g_loss:0.4211
# epoch:6  d_loss:0.4875  g_loss:0.6973
# epoch:7  d_loss:0.5091  g_loss:0.8700
# epoch:8  d_loss:0.4967  g_loss:0.8962
# epoch:9  d_loss:0.4865  g_loss:0.8708
# epoch:10  d_loss:0.4183  g_loss:0.7831
# epoch:11  d_loss:0.4412  g_loss:0.8053
# epoch:12  d_loss:0.4846  g_loss:0.8588
# epoch:13  d_loss:0.4794  g_loss:0.9090
# epoch:14  d_loss:0.5748  g_loss:0.9677
# epoch:15  d_loss:0.4742  g_loss:1.0391
# epoch:16  d_loss:0.4031  g_loss:1.0546
# epoch:17  d_loss:0.6225  g_loss:0.7794
# epoch:18  d_loss:0.5672  g_loss:0.6417
# epoch:19  d_loss:0.4564  g_loss:0.7210
# epoch:20  d_loss:0.4228  g_loss:0.7950
# epoch:21  d_loss:0.4978  g_loss:0.8289
# epoch:22  d_loss:0.5131  g_loss:0.6645
# epoch:23  d_loss:0.4513  g_loss:0.6105
# epoch:24  d_loss:0.4464  g_loss:0.6672
# epoch:25  d_loss:0.4641  g_loss:0.7186
# epoch:26  d_loss:0.5040  g_loss:0.7497
# epoch:27  d_loss:0.4719  g_loss:0.5928
# epoch:28  d_loss:0.4888  g_loss:0.5307
# epoch:29  d_loss:0.5126  g_loss:0.5505
# epoch:30  d_loss:0.4486  g_loss:0.6409
# epoch:31  d_loss:0.4647  g_loss:0.6741
# epoch:32  d_loss:0.4161  g_loss:0.5664
# epoch:33  d_loss:0.4175  g_loss:0.6050
# epoch:34  d_loss:0.3205  g_loss:0.6914
# epoch:35  d_loss:0.3645  g_loss:0.8391
# epoch:36  d_loss:0.4118  g_loss:0.5996
# epoch:37  d_loss:0.3483  g_loss:0.7468
# epoch:38  d_loss:0.3391  g_loss:0.9159
# epoch:39  d_loss:0.2180  g_loss:1.3084
# epoch:40  d_loss:0.3222  g_loss:1.2722
# epoch:41  d_loss:0.4196  g_loss:0.9065
# epoch:42  d_loss:0.3850  g_loss:0.8834
# epoch:43  d_loss:0.2302  g_loss:1.2762
# epoch:44  d_loss:0.2145  g_loss:1.5809
# epoch:45  d_loss:0.1780  g_loss:2.2293
# epoch:46  d_loss:0.3839  g_loss:1.5924
# epoch:47  d_loss:0.3088  g_loss:1.0249
# epoch:48  d_loss:0.3390  g_loss:1.1715
# epoch:49  d_loss:0.3346  g_loss:1.7949
# epoch:50  d_loss:0.2771  g_loss:2.4256
# epoch:51  d_loss:0.3444  g_loss:2.4457
# epoch:52  d_loss:0.1938  g_loss:1.9744
# epoch:53  d_loss:0.1472  g_loss:1.3832
# epoch:54  d_loss:0.1097  g_loss:1.9667
# epoch:55  d_loss:0.0997  g_loss:2.7828
# epoch:56  d_loss:0.1234  g_loss:2.5205
# epoch:57  d_loss:0.3150  g_loss:2.1563
# epoch:58  d_loss:0.2852  g_loss:2.8375
# epoch:59  d_loss:0.4759  g_loss:2.1547
# epoch:60  d_loss:0.6827  g_loss:2.3578
# epoch:61  d_loss:0.6025  g_loss:2.7588
# epoch:62  d_loss:0.8821  g_loss:2.1593
# epoch:63  d_loss:0.6249  g_loss:2.5152
# epoch:64  d_loss:0.4155  g_loss:3.1849
# epoch:65  d_loss:0.5762  g_loss:3.6130
# epoch:66  d_loss:0.3454  g_loss:3.0120
# epoch:67  d_loss:0.2588  g_loss:3.6806
# epoch:68  d_loss:0.1548  g_loss:3.9188
# epoch:69  d_loss:0.4268  g_loss:3.4063
# epoch:70  d_loss:0.5344  g_loss:2.2282
# epoch:71  d_loss:0.4049  g_loss:1.6349
# epoch:72  d_loss:0.6076  g_loss:1.8771
# epoch:73  d_loss:0.3816  g_loss:2.4270
# epoch:74  d_loss:0.9062  g_loss:1.1764
# epoch:75  d_loss:0.9921  g_loss:0.8026
# epoch:76  d_loss:0.6963  g_loss:1.1927
# epoch:77  d_loss:0.6801  g_loss:2.0636
# epoch:78  d_loss:0.6217  g_loss:2.1906
# epoch:79  d_loss:0.3997  g_loss:2.4358
# epoch:80  d_loss:0.2880  g_loss:2.4142
# epoch:81  d_loss:0.2337  g_loss:2.9891
# epoch:82  d_loss:0.1542  g_loss:3.7463
# epoch:83  d_loss:0.1213  g_loss:5.2708
# epoch:84  d_loss:0.1926  g_loss:5.2032
# epoch:85  d_loss:0.5071  g_loss:4.2574
# epoch:86  d_loss:0.3987  g_loss:4.6752
# epoch:87  d_loss:0.7792  g_loss:4.9081
# epoch:88  d_loss:0.8614  g_loss:4.8093
# epoch:89  d_loss:1.2651  g_loss:3.4970
# epoch:90  d_loss:0.9311  g_loss:3.9754
# epoch:91  d_loss:0.8685  g_loss:3.9768
# epoch:92  d_loss:1.1018  g_loss:2.5753
# epoch:93  d_loss:1.0410  g_loss:2.0691
# epoch:94  d_loss:0.9711  g_loss:1.6028
# epoch:95  d_loss:0.6163  g_loss:1.8403
# epoch:96  d_loss:0.6152  g_loss:1.8898
# epoch:97  d_loss:0.5163  g_loss:1.9671
# epoch:98  d_loss:0.4697  g_loss:1.8447
# epoch:99  d_loss:0.4834  g_loss:1.7385
# epoch:100  d_loss:0.5267  g_loss:1.5112
# epoch:101  d_loss:0.3436  g_loss:1.5402
# epoch:102  d_loss:0.3357  g_loss:1.4834
# epoch:103  d_loss:0.4552  g_loss:1.1235
# epoch:104  d_loss:0.2930  g_loss:1.2686
# epoch:105  d_loss:0.4464  g_loss:1.4934
# epoch:106  d_loss:0.4210  g_loss:1.2210
# epoch:107  d_loss:0.3592  g_loss:1.4375
# epoch:108  d_loss:0.3939  g_loss:1.2405
# epoch:109  d_loss:0.3654  g_loss:1.1574
# epoch:110  d_loss:0.3165  g_loss:1.3236
# epoch:111  d_loss:0.4099  g_loss:1.0575
# epoch:112  d_loss:0.3761  g_loss:1.1026
# epoch:113  d_loss:0.4266  g_loss:1.0269
# epoch:114  d_loss:0.5435  g_loss:1.0280
# epoch:115  d_loss:0.4813  g_loss:0.9703
# epoch:116  d_loss:0.4511  g_loss:0.9660
# epoch:117  d_loss:0.4921  g_loss:0.9312
# epoch:118  d_loss:0.5050  g_loss:1.0279
# epoch:119  d_loss:0.3823  g_loss:1.0378
# epoch:120  d_loss:0.6268  g_loss:0.7367
# epoch:121  d_loss:0.7012  g_loss:0.9081
# epoch:122  d_loss:0.8233  g_loss:0.8872
# epoch:123  d_loss:0.6721  g_loss:0.9300
# epoch:124  d_loss:0.7136  g_loss:0.8458
# epoch:125  d_loss:0.8843  g_loss:0.9218
# epoch:126  d_loss:0.8036  g_loss:0.7969
# epoch:127  d_loss:0.7270  g_loss:0.9028
# epoch:128  d_loss:0.6760  g_loss:1.0364
# epoch:129  d_loss:0.6293  g_loss:1.1365
# epoch:130  d_loss:0.5652  g_loss:1.1024
# epoch:131  d_loss:0.6240  g_loss:1.2956
# epoch:132  d_loss:0.6149  g_loss:1.1227
# epoch:133  d_loss:0.5896  g_loss:1.3824
# epoch:134  d_loss:0.4835  g_loss:1.3839
# epoch:135  d_loss:0.4622  g_loss:1.5519
# epoch:136  d_loss:0.4203  g_loss:1.5586
# epoch:137  d_loss:0.3510  g_loss:1.8153
# epoch:138  d_loss:0.3451  g_loss:1.9642
# epoch:139  d_loss:0.2941  g_loss:2.0955
# epoch:140  d_loss:0.3020  g_loss:2.0704
# epoch:141  d_loss:0.3186  g_loss:2.3916
# epoch:142  d_loss:0.2958  g_loss:2.4248
# epoch:143  d_loss:0.2851  g_loss:2.2077
# epoch:144  d_loss:0.3357  g_loss:2.4293
# epoch:145  d_loss:0.2611  g_loss:2.8830
# epoch:146  d_loss:0.4032  g_loss:2.6164
# epoch:147  d_loss:0.6165  g_loss:2.2103
# epoch:148  d_loss:0.5673  g_loss:2.0552
# epoch:149  d_loss:0.6172  g_loss:2.0144
# epoch:150  d_loss:0.4364  g_loss:2.4832
# epoch:151  d_loss:0.6905  g_loss:2.4064
# epoch:152  d_loss:0.8146  g_loss:1.7909
# epoch:153  d_loss:0.7186  g_loss:1.6162
# epoch:154  d_loss:0.6862  g_loss:1.3814
# epoch:155  d_loss:0.8020  g_loss:1.1194
# epoch:156  d_loss:0.7278  g_loss:1.2849
# epoch:157  d_loss:0.5734  g_loss:1.6702
# epoch:158  d_loss:0.5461  g_loss:1.6348
# epoch:159  d_loss:0.6149  g_loss:1.5596
# epoch:160  d_loss:0.6320  g_loss:1.6074
# epoch:161  d_loss:0.5744  g_loss:1.5768
# epoch:162  d_loss:0.5374  g_loss:1.4574
# epoch:163  d_loss:0.5382  g_loss:1.6331
# epoch:164  d_loss:0.4774  g_loss:1.5964
# epoch:165  d_loss:0.3930  g_loss:1.7763
# epoch:166  d_loss:0.4306  g_loss:1.7247
# epoch:167  d_loss:0.4852  g_loss:1.6871
# epoch:168  d_loss:0.4258  g_loss:1.5277
# epoch:169  d_loss:0.4834  g_loss:1.7055
# epoch:170  d_loss:0.4180  g_loss:1.4997
# epoch:171  d_loss:0.4332  g_loss:1.5105
# epoch:172  d_loss:0.3812  g_loss:1.4194
# epoch:173  d_loss:0.3235  g_loss:1.6218
# epoch:174  d_loss:0.4146  g_loss:1.6838
# epoch:175  d_loss:0.3421  g_loss:1.8468
# epoch:176  d_loss:0.4688  g_loss:1.8176
# epoch:177  d_loss:0.4044  g_loss:1.9631
# epoch:178  d_loss:0.3050  g_loss:1.7941
# epoch:179  d_loss:0.3544  g_loss:1.5864
# epoch:180  d_loss:0.4460  g_loss:1.6629
# epoch:181  d_loss:0.3332  g_loss:2.0389
# epoch:182  d_loss:0.4044  g_loss:1.9457
# epoch:183  d_loss:0.3445  g_loss:1.9092
# epoch:184  d_loss:0.3628  g_loss:1.3679
# epoch:185  d_loss:0.4691  g_loss:1.4199
# epoch:186  d_loss:0.3748  g_loss:1.8200
# epoch:187  d_loss:0.4477  g_loss:1.6280
# epoch:188  d_loss:0.5864  g_loss:1.3490
# epoch:189  d_loss:0.4662  g_loss:1.2892
# epoch:190  d_loss:0.4029  g_loss:1.8643
# epoch:191  d_loss:0.5575  g_loss:1.7463
# epoch:192  d_loss:0.5555  g_loss:1.6062
# epoch:193  d_loss:0.5942  g_loss:1.3192
# epoch:194  d_loss:0.5378  g_loss:1.2569
# epoch:195  d_loss:0.5349  g_loss:1.1366
# epoch:196  d_loss:0.6193  g_loss:1.1818
# epoch:197  d_loss:0.3990  g_loss:1.6045
# epoch:198  d_loss:0.5498  g_loss:1.7734
# epoch:199  d_loss:0.6170  g_loss:1.5667
# epoch:200  d_loss:0.5853  g_loss:1.3204
# epoch:201  d_loss:0.5179  g_loss:1.1256
# epoch:202  d_loss:0.6931  g_loss:1.1956
# epoch:203  d_loss:0.3751  g_loss:1.9254
# epoch:204  d_loss:0.5199  g_loss:1.6857
# epoch:205  d_loss:0.5035  g_loss:1.6165
# epoch:206  d_loss:0.5111  g_loss:1.8119
# epoch:207  d_loss:0.6063  g_loss:1.4648
# epoch:208  d_loss:0.6251  g_loss:1.6088
# epoch:209  d_loss:0.4465  g_loss:1.4735
# epoch:210  d_loss:0.5211  g_loss:1.6889
# epoch:211  d_loss:0.4916  g_loss:1.9064
# epoch:212  d_loss:0.4926  g_loss:1.7887
# epoch:213  d_loss:0.6706  g_loss:1.5994
# epoch:214  d_loss:0.5832  g_loss:1.3759
# epoch:215  d_loss:0.4655  g_loss:1.4926
# epoch:216  d_loss:0.6034  g_loss:1.7762
# epoch:217  d_loss:0.4854  g_loss:1.7910
# epoch:218  d_loss:0.4725  g_loss:1.8153
# epoch:219  d_loss:0.5205  g_loss:1.5571
# epoch:220  d_loss:0.5360  g_loss:1.4067
# epoch:221  d_loss:0.5328  g_loss:1.6343
# epoch:222  d_loss:0.5258  g_loss:1.4551
# epoch:223  d_loss:0.5180  g_loss:1.7258
# epoch:224  d_loss:0.4675  g_loss:2.0626
# epoch:225  d_loss:0.4483  g_loss:1.5340
# epoch:226  d_loss:0.4240  g_loss:1.8133
# epoch:227  d_loss:0.5485  g_loss:1.6028
# epoch:228  d_loss:0.4828  g_loss:1.7935
# epoch:229  d_loss:0.4463  g_loss:1.6732
# epoch:230  d_loss:0.4513  g_loss:1.7064
# epoch:231  d_loss:0.5378  g_loss:1.8350
# epoch:232  d_loss:0.5297  g_loss:1.8133
# epoch:233  d_loss:0.5570  g_loss:1.7891
# epoch:234  d_loss:0.4738  g_loss:1.6572
# epoch:235  d_loss:0.3907  g_loss:1.5199
# epoch:236  d_loss:0.4456  g_loss:1.5451
# epoch:237  d_loss:0.4144  g_loss:1.7419
# epoch:238  d_loss:0.4895  g_loss:1.7406
# epoch:239  d_loss:0.3885  g_loss:1.8739
# epoch:240  d_loss:0.4831  g_loss:1.9503
# epoch:241  d_loss:0.6577  g_loss:1.7428
# epoch:242  d_loss:0.5363  g_loss:1.4922
# epoch:243  d_loss:0.5546  g_loss:1.4142
# epoch:244  d_loss:0.5338  g_loss:1.2942
# epoch:245  d_loss:0.4219  g_loss:1.5791
# epoch:246  d_loss:0.5511  g_loss:1.9255
# epoch:247  d_loss:0.4897  g_loss:2.0101
# epoch:248  d_loss:0.4188  g_loss:1.9425
# epoch:249  d_loss:0.5522  g_loss:1.8947
# epoch:250  d_loss:0.4185  g_loss:1.6377
# epoch:251  d_loss:0.4410  g_loss:1.5060
# epoch:252  d_loss:0.3954  g_loss:1.5485
# epoch:253  d_loss:0.5162  g_loss:1.6148
# epoch:254  d_loss:0.4277  g_loss:1.8658
# epoch:255  d_loss:0.7021  g_loss:1.8650
# epoch:256  d_loss:0.5096  g_loss:1.6395
# epoch:257  d_loss:0.4695  g_loss:1.4668
# epoch:258  d_loss:0.5254  g_loss:1.5157
# epoch:259  d_loss:0.5178  g_loss:1.5877
# epoch:260  d_loss:0.5275  g_loss:1.5599
# epoch:261  d_loss:0.4725  g_loss:1.4371
# epoch:262  d_loss:0.5052  g_loss:1.8236
# epoch:263  d_loss:0.4557  g_loss:2.0952
# epoch:264  d_loss:0.4802  g_loss:1.8984
# epoch:265  d_loss:0.6108  g_loss:1.4613
# epoch:266  d_loss:0.4527  g_loss:1.4632
# epoch:267  d_loss:0.5178  g_loss:1.9160
# epoch:268  d_loss:0.4167  g_loss:1.8417
# epoch:269  d_loss:0.5228  g_loss:1.8236
# epoch:270  d_loss:0.3526  g_loss:2.4012
# epoch:271  d_loss:0.4111  g_loss:2.1978
# epoch:272  d_loss:0.3681  g_loss:1.8187
# epoch:273  d_loss:0.3839  g_loss:2.0103
# epoch:274  d_loss:0.4038  g_loss:1.9779
# epoch:275  d_loss:0.3145  g_loss:2.1445
# epoch:276  d_loss:0.5285  g_loss:2.1473
# epoch:277  d_loss:0.5086  g_loss:2.1157
# epoch:278  d_loss:0.2801  g_loss:2.4079
# epoch:279  d_loss:0.4632  g_loss:2.2199
# epoch:280  d_loss:0.4930  g_loss:1.4657
# epoch:281  d_loss:0.5137  g_loss:2.3327
# epoch:282  d_loss:0.4035  g_loss:2.2565
# epoch:283  d_loss:0.4380  g_loss:2.3652
# epoch:284  d_loss:0.5654  g_loss:2.0842
# epoch:285  d_loss:0.5039  g_loss:1.8758
# epoch:286  d_loss:0.5902  g_loss:2.0052
# epoch:287  d_loss:0.5553  g_loss:2.1328
# epoch:288  d_loss:0.5621  g_loss:1.9161
# epoch:289  d_loss:0.6199  g_loss:1.8962
# epoch:290  d_loss:0.5732  g_loss:1.9660
# epoch:291  d_loss:0.6231  g_loss:1.6013
# epoch:292  d_loss:0.7104  g_loss:1.5459
# epoch:293  d_loss:0.4782  g_loss:1.8358
# epoch:294  d_loss:0.4702  g_loss:1.7323
# epoch:295  d_loss:0.5745  g_loss:1.6848
# epoch:296  d_loss:0.5494  g_loss:1.4290
# epoch:297  d_loss:0.5901  g_loss:1.8731
# epoch:298  d_loss:0.5013  g_loss:1.8714
# epoch:299  d_loss:0.6073  g_loss:1.4106
# epoch:300  d_loss:0.5745  g_loss:2.0260
# epoch:301  d_loss:0.5493  g_loss:1.5827
# epoch:302  d_loss:0.4233  g_loss:1.8679
# epoch:303  d_loss:0.4703  g_loss:1.7493
# epoch:304  d_loss:0.4795  g_loss:1.4345
# epoch:305  d_loss:0.5913  g_loss:1.5013
# epoch:306  d_loss:0.3156  g_loss:2.0567
# epoch:307  d_loss:0.5464  g_loss:1.8531
# epoch:308  d_loss:0.3341  g_loss:2.1242
# epoch:309  d_loss:0.3856  g_loss:1.9436
# epoch:310  d_loss:0.4406  g_loss:1.9750
# epoch:311  d_loss:0.3560  g_loss:1.6770
# epoch:312  d_loss:0.4221  g_loss:1.7368
# epoch:313  d_loss:0.3764  g_loss:1.8933
# epoch:314  d_loss:0.3823  g_loss:2.2382
# epoch:315  d_loss:0.3298  g_loss:1.8337
# epoch:316  d_loss:0.3747  g_loss:1.9656
# epoch:317  d_loss:0.2507  g_loss:2.4998
# epoch:318  d_loss:0.4661  g_loss:1.9229
# epoch:319  d_loss:0.3435  g_loss:2.3412
# epoch:320  d_loss:0.3011  g_loss:2.4044
# epoch:321  d_loss:0.3837  g_loss:2.2737
# epoch:322  d_loss:0.3778  g_loss:2.0395
# epoch:323  d_loss:0.4211  g_loss:1.8334
# epoch:324  d_loss:0.3886  g_loss:2.0728
# epoch:325  d_loss:0.3436  g_loss:1.7774
# epoch:326  d_loss:0.5448  g_loss:1.9200
# epoch:327  d_loss:0.4490  g_loss:1.7738
# epoch:328  d_loss:0.3700  g_loss:2.2700
# epoch:329  d_loss:0.4890  g_loss:2.1998
# epoch:330  d_loss:0.4694  g_loss:2.1193
# epoch:331  d_loss:0.5117  g_loss:2.1556
# epoch:332  d_loss:0.5632  g_loss:1.8763
# epoch:333  d_loss:0.6956  g_loss:1.6397
# epoch:334  d_loss:0.5214  g_loss:1.6126
# epoch:335  d_loss:0.6096  g_loss:1.4734
# epoch:336  d_loss:0.4570  g_loss:1.6016
# epoch:337  d_loss:0.4707  g_loss:1.7324
# epoch:338  d_loss:0.5552  g_loss:2.0285
# epoch:339  d_loss:0.5429  g_loss:2.0242
# epoch:340  d_loss:0.3841  g_loss:2.0068
# epoch:341  d_loss:0.5906  g_loss:1.5236
# epoch:342  d_loss:0.5330  g_loss:1.4841
# epoch:343  d_loss:0.6283  g_loss:1.6698
# epoch:344  d_loss:0.4734  g_loss:1.7484
# epoch:345  d_loss:0.4917  g_loss:2.3922
# epoch:346  d_loss:0.6218  g_loss:1.7470
# epoch:347  d_loss:0.4850  g_loss:1.8719
# epoch:348  d_loss:0.4798  g_loss:2.1849
# epoch:349  d_loss:0.4128  g_loss:2.3519
# epoch:350  d_loss:0.4839  g_loss:1.9501
# epoch:351  d_loss:0.4090  g_loss:1.9613
# epoch:352  d_loss:0.4249  g_loss:1.8988
# epoch:353  d_loss:0.4210  g_loss:1.8505
# epoch:354  d_loss:0.5525  g_loss:1.8803
# epoch:355  d_loss:0.3595  g_loss:1.8086
# epoch:356  d_loss:0.3478  g_loss:1.7203
# epoch:357  d_loss:0.3239  g_loss:2.0674
# epoch:358  d_loss:0.3059  g_loss:2.9061
# epoch:359  d_loss:0.2949  g_loss:3.4711
# epoch:360  d_loss:0.4106  g_loss:3.0289
# epoch:361  d_loss:0.3241  g_loss:2.8641
# epoch:362  d_loss:0.2332  g_loss:2.9813
# epoch:363  d_loss:0.3299  g_loss:2.2820
# epoch:364  d_loss:0.3104  g_loss:2.1106
# epoch:365  d_loss:0.2665  g_loss:2.2722
# epoch:366  d_loss:0.3664  g_loss:1.9612
# epoch:367  d_loss:0.3137  g_loss:2.6341
# epoch:368  d_loss:0.3033  g_loss:2.4498
# epoch:369  d_loss:0.4220  g_loss:2.4092
# epoch:370  d_loss:0.4629  g_loss:2.1907
# epoch:371  d_loss:0.3338  g_loss:2.3040
# epoch:372  d_loss:0.3545  g_loss:2.1316
# epoch:373  d_loss:0.3791  g_loss:1.9411
# epoch:374  d_loss:0.2537  g_loss:2.7594
# epoch:375  d_loss:0.3283  g_loss:3.3346
# epoch:376  d_loss:0.3525  g_loss:2.7086
# epoch:377  d_loss:0.3373  g_loss:2.3350
# epoch:378  d_loss:0.3005  g_loss:2.2443
# epoch:379  d_loss:0.3825  g_loss:2.2446
# epoch:380  d_loss:0.4810  g_loss:2.2563
# epoch:381  d_loss:0.3750  g_loss:3.0543
# epoch:382  d_loss:0.2880  g_loss:2.6996
# epoch:383  d_loss:0.3996  g_loss:2.9704
# epoch:384  d_loss:0.2753  g_loss:2.0729
# epoch:385  d_loss:0.4243  g_loss:1.7887
# epoch:386  d_loss:0.4104  g_loss:1.5384
# epoch:387  d_loss:0.2946  g_loss:1.8436
# epoch:388  d_loss:0.4681  g_loss:2.2506
# epoch:389  d_loss:0.2922  g_loss:2.4459
# epoch:390  d_loss:0.5673  g_loss:2.3064
# epoch:391  d_loss:0.3346  g_loss:1.9909
# epoch:392  d_loss:0.5443  g_loss:1.5000
# epoch:393  d_loss:0.5294  g_loss:1.4946
# epoch:394  d_loss:0.5178  g_loss:1.4697
# epoch:395  d_loss:0.4546  g_loss:2.3090
# epoch:396  d_loss:0.5045  g_loss:2.0336
# epoch:397  d_loss:0.5008  g_loss:2.3218
# epoch:398  d_loss:0.6389  g_loss:1.3246
# epoch:399  d_loss:0.6280  g_loss:1.2662
# epoch:400  d_loss:0.4974  g_loss:1.2156
# epoch:401  d_loss:0.3518  g_loss:1.6166
# epoch:402  d_loss:0.4543  g_loss:1.7706
# epoch:403  d_loss:0.4132  g_loss:2.0090
# epoch:404  d_loss:0.4532  g_loss:1.7882
# epoch:405  d_loss:0.4102  g_loss:1.6244
# epoch:406  d_loss:0.3922  g_loss:1.3669
# epoch:407  d_loss:0.4105  g_loss:1.7943
# epoch:408  d_loss:0.3884  g_loss:2.1429
# epoch:409  d_loss:0.3125  g_loss:1.9239
# epoch:410  d_loss:0.3952  g_loss:2.3543
# epoch:411  d_loss:0.3586  g_loss:2.1128
# epoch:412  d_loss:0.3397  g_loss:1.9871
# epoch:413  d_loss:0.4289  g_loss:1.7101
# epoch:414  d_loss:0.4648  g_loss:1.3635
# epoch:415  d_loss:0.4161  g_loss:1.9510
# epoch:416  d_loss:0.4219  g_loss:1.9064
# epoch:417  d_loss:0.2840  g_loss:2.2133
# epoch:418  d_loss:0.3534  g_loss:1.9230
# epoch:419  d_loss:0.3723  g_loss:1.8553
# epoch:420  d_loss:0.3004  g_loss:1.9773
# epoch:421  d_loss:0.3177  g_loss:2.5549
# epoch:422  d_loss:0.3990  g_loss:1.8630
# epoch:423  d_loss:0.3325  g_loss:2.0613
# epoch:424  d_loss:0.4624  g_loss:1.8620
# epoch:425  d_loss:0.2916  g_loss:2.0899
# epoch:426  d_loss:0.2664  g_loss:2.3181
# epoch:427  d_loss:0.2967  g_loss:2.8079
# epoch:428  d_loss:0.2781  g_loss:2.8305
# epoch:429  d_loss:0.3515  g_loss:2.7583
# epoch:430  d_loss:0.3125  g_loss:2.3523
# epoch:431  d_loss:0.2447  g_loss:2.8537
# epoch:432  d_loss:0.3193  g_loss:2.2769
# epoch:433  d_loss:0.1825  g_loss:2.5835
# epoch:434  d_loss:0.2685  g_loss:2.1848
# epoch:435  d_loss:0.2264  g_loss:2.4318
# epoch:436  d_loss:0.2141  g_loss:2.4330
# epoch:437  d_loss:0.2705  g_loss:2.4386
# epoch:438  d_loss:0.2813  g_loss:2.3661
# epoch:439  d_loss:0.1577  g_loss:3.4477
# epoch:440  d_loss:0.2800  g_loss:2.8549
# epoch:441  d_loss:0.2419  g_loss:2.2249
# epoch:442  d_loss:0.3277  g_loss:2.4572
# epoch:443  d_loss:0.2183  g_loss:2.1317
# epoch:444  d_loss:0.3449  g_loss:2.4280
# epoch:445  d_loss:0.3664  g_loss:2.3252
# epoch:446  d_loss:0.2635  g_loss:2.5001
# epoch:447  d_loss:0.3793  g_loss:2.7819
# epoch:448  d_loss:0.4798  g_loss:2.4768
# epoch:449  d_loss:0.4364  g_loss:2.3666
# epoch:450  d_loss:0.3919  g_loss:2.5995
# epoch:451  d_loss:0.3608  g_loss:2.8764
# epoch:452  d_loss:0.4423  g_loss:2.3913
# epoch:453  d_loss:0.4585  g_loss:2.3221
# epoch:454  d_loss:0.3712  g_loss:2.3864
# epoch:455  d_loss:0.6319  g_loss:1.6886
# epoch:456  d_loss:0.5271  g_loss:1.8818
# epoch:457  d_loss:0.4280  g_loss:1.5775
# epoch:458  d_loss:0.5669  g_loss:2.0886
# epoch:459  d_loss:0.4805  g_loss:2.4872
# epoch:460  d_loss:0.3604  g_loss:2.2496
# epoch:461  d_loss:0.5605  g_loss:1.9413
# epoch:462  d_loss:0.4969  g_loss:1.9175
# epoch:463  d_loss:0.4446  g_loss:2.0760
# epoch:464  d_loss:0.2044  g_loss:3.1275
# epoch:465  d_loss:0.3238  g_loss:3.0998
# epoch:466  d_loss:0.3356  g_loss:2.3409
# epoch:467  d_loss:0.3242  g_loss:2.4011
# epoch:468  d_loss:0.1959  g_loss:2.1288
# epoch:469  d_loss:0.3047  g_loss:2.4946
# epoch:470  d_loss:0.2524  g_loss:2.8174
# epoch:471  d_loss:0.3644  g_loss:2.4176
# epoch:472  d_loss:0.2445  g_loss:2.1734
# epoch:473  d_loss:0.2710  g_loss:2.2516
# epoch:474  d_loss:0.3112  g_loss:2.0460
# epoch:475  d_loss:0.2775  g_loss:2.1565
# epoch:476  d_loss:0.1701  g_loss:2.7921
# epoch:477  d_loss:0.2380  g_loss:2.8401
# epoch:478  d_loss:0.1663  g_loss:3.6982
# epoch:479  d_loss:0.2006  g_loss:3.1816
# epoch:480  d_loss:0.2966  g_loss:2.9011
# epoch:481  d_loss:0.1931  g_loss:2.9603
# epoch:482  d_loss:0.3065  g_loss:2.7647
# epoch:483  d_loss:0.2107  g_loss:2.3860
# epoch:484  d_loss:0.1792  g_loss:2.2304
# epoch:485  d_loss:0.2727  g_loss:2.2983
# epoch:486  d_loss:0.2178  g_loss:2.5142
# epoch:487  d_loss:0.3476  g_loss:2.6072
# epoch:488  d_loss:0.3126  g_loss:2.3977
# epoch:489  d_loss:0.2452  g_loss:2.5986
# epoch:490  d_loss:0.2239  g_loss:2.5991
# epoch:491  d_loss:0.2386  g_loss:2.9681
# epoch:492  d_loss:0.2252  g_loss:2.3482
# epoch:493  d_loss:0.2447  g_loss:2.8732
# epoch:494  d_loss:0.2415  g_loss:2.7467
# epoch:495  d_loss:0.1806  g_loss:2.8895
# epoch:496  d_loss:0.2523  g_loss:2.5268
# epoch:497  d_loss:0.1931  g_loss:2.5789
# epoch:498  d_loss:0.3153  g_loss:1.7784
# epoch:499  d_loss:0.3131  g_loss:1.8489
# epoch:500  d_loss:0.3682  g_loss:2.1223
# epoch:501  d_loss:0.1993  g_loss:2.7149
# epoch:502  d_loss:0.2750  g_loss:3.3540
# epoch:503  d_loss:0.3521  g_loss:2.7446
# epoch:504  d_loss:0.3506  g_loss:2.3821
# epoch:505  d_loss:0.2408  g_loss:1.9361
# epoch:506  d_loss:0.2992  g_loss:2.4099
# epoch:507  d_loss:0.2864  g_loss:2.6051
# epoch:508  d_loss:0.2219  g_loss:2.7374
# epoch:509  d_loss:0.4297  g_loss:2.1650
# epoch:510  d_loss:0.2953  g_loss:2.3776
# epoch:511  d_loss:0.2898  g_loss:2.5299
# epoch:512  d_loss:0.2498  g_loss:2.6923
# epoch:513  d_loss:0.2681  g_loss:2.4419
# epoch:514  d_loss:0.3370  g_loss:2.2147
# epoch:515  d_loss:0.2518  g_loss:2.2939
# epoch:516  d_loss:0.2694  g_loss:2.4673
# epoch:517  d_loss:0.2326  g_loss:2.7203
# epoch:518  d_loss:0.3097  g_loss:3.2865
# epoch:519  d_loss:0.3474  g_loss:2.3561
# epoch:520  d_loss:0.2162  g_loss:2.3013
# epoch:521  d_loss:0.2623  g_loss:2.3740
# epoch:522  d_loss:0.2451  g_loss:2.3903
# epoch:523  d_loss:0.2957  g_loss:2.3720
# epoch:524  d_loss:0.2419  g_loss:2.7321
# epoch:525  d_loss:0.2943  g_loss:2.2905
# epoch:526  d_loss:0.2362  g_loss:2.3705
# epoch:527  d_loss:0.2743  g_loss:2.0646
# epoch:528  d_loss:0.2222  g_loss:2.4322
# epoch:529  d_loss:0.2293  g_loss:1.8482
# epoch:530  d_loss:0.3234  g_loss:1.6628
# epoch:531  d_loss:0.1913  g_loss:2.4102
# epoch:532  d_loss:0.1421  g_loss:2.7217
# epoch:533  d_loss:0.2998  g_loss:2.7437
# epoch:534  d_loss:0.1410  g_loss:2.5700
# epoch:535  d_loss:0.1726  g_loss:2.1854
# epoch:536  d_loss:0.2347  g_loss:2.7292
# epoch:537  d_loss:0.2078  g_loss:3.1314
# epoch:538  d_loss:0.1718  g_loss:2.5232
# epoch:539  d_loss:0.2478  g_loss:2.5180
# epoch:540  d_loss:0.1647  g_loss:2.8959
# epoch:541  d_loss:0.1768  g_loss:2.4822
# epoch:542  d_loss:0.2702  g_loss:2.5716
# epoch:543  d_loss:0.3604  g_loss:2.4487
# epoch:544  d_loss:0.3683  g_loss:2.1340
# epoch:545  d_loss:0.4479  g_loss:1.9099
# epoch:546  d_loss:0.3846  g_loss:1.6977
# epoch:547  d_loss:0.2946  g_loss:2.2439
# epoch:548  d_loss:0.3917  g_loss:2.0339
# epoch:549  d_loss:0.5677  g_loss:2.2416
# epoch:550  d_loss:0.3626  g_loss:1.7077
# epoch:551  d_loss:0.3018  g_loss:2.7675
# epoch:552  d_loss:0.3972  g_loss:3.2125
# epoch:553  d_loss:0.4450  g_loss:2.3010
# epoch:554  d_loss:0.3996  g_loss:1.9628
# epoch:555  d_loss:0.4101  g_loss:2.1221
# epoch:556  d_loss:0.2119  g_loss:3.5649
# epoch:557  d_loss:0.2534  g_loss:3.3246
# epoch:558  d_loss:0.4589  g_loss:2.0894
# epoch:559  d_loss:0.2432  g_loss:2.2451
# epoch:560  d_loss:0.4065  g_loss:1.6860
# epoch:561  d_loss:0.3892  g_loss:2.1799
# epoch:562  d_loss:0.2600  g_loss:1.9491
# epoch:563  d_loss:0.3943  g_loss:2.4733
# epoch:564  d_loss:0.4116  g_loss:1.9716
# epoch:565  d_loss:0.3305  g_loss:1.9943
# epoch:566  d_loss:0.3648  g_loss:2.1819
# epoch:567  d_loss:0.2554  g_loss:2.5421
# epoch:568  d_loss:0.3453  g_loss:2.0424
# epoch:569  d_loss:0.2207  g_loss:2.3646
# epoch:570  d_loss:0.3402  g_loss:1.9598
# epoch:571  d_loss:0.3086  g_loss:2.3229
# epoch:572  d_loss:0.2347  g_loss:2.0878
# epoch:573  d_loss:0.3965  g_loss:2.2095
# epoch:574  d_loss:0.2776  g_loss:2.1150
# epoch:575  d_loss:0.3139  g_loss:1.7111
# epoch:576  d_loss:0.3084  g_loss:1.9343
# epoch:577  d_loss:0.2526  g_loss:1.8483
# epoch:578  d_loss:0.5417  g_loss:1.8403
# epoch:579  d_loss:0.2970  g_loss:2.0584
# epoch:580  d_loss:0.3571  g_loss:2.2948
# epoch:581  d_loss:0.3348  g_loss:2.6950
# epoch:582  d_loss:0.2921  g_loss:1.8305
# epoch:583  d_loss:0.3278  g_loss:2.4973
# epoch:584  d_loss:0.3367  g_loss:2.6691
# epoch:585  d_loss:0.2628  g_loss:2.9934
# epoch:586  d_loss:0.2841  g_loss:2.8727
# epoch:587  d_loss:0.4625  g_loss:2.1571
# epoch:588  d_loss:0.6021  g_loss:1.6473
# epoch:589  d_loss:0.3474  g_loss:2.1991
# epoch:590  d_loss:0.4036  g_loss:2.1457
# epoch:591  d_loss:0.3885  g_loss:2.6788
# epoch:592  d_loss:0.3768  g_loss:1.9829
# epoch:593  d_loss:0.4303  g_loss:2.0473
# epoch:594  d_loss:0.4023  g_loss:1.3692
# epoch:595  d_loss:0.7019  g_loss:1.9907
# epoch:596  d_loss:0.5085  g_loss:2.0676
# epoch:597  d_loss:0.5987  g_loss:1.7491
# epoch:598  d_loss:0.6620  g_loss:1.4408
# epoch:599  d_loss:0.5542  g_loss:1.3819
# epoch:600  d_loss:0.6859  g_loss:2.0115
# epoch:601  d_loss:0.5974  g_loss:2.6352
# epoch:602  d_loss:0.9172  g_loss:2.0357
# epoch:603  d_loss:0.5759  g_loss:1.9354
# epoch:604  d_loss:0.6454  g_loss:1.6180
# epoch:605  d_loss:0.3615  g_loss:1.8853
# epoch:606  d_loss:0.5067  g_loss:1.4537
# epoch:607  d_loss:0.3836  g_loss:2.3132
# epoch:608  d_loss:0.4193  g_loss:2.2239
# epoch:609  d_loss:0.3683  g_loss:2.6817
# epoch:610  d_loss:0.4066  g_loss:2.1245
# epoch:611  d_loss:0.2786  g_loss:2.2737
# epoch:612  d_loss:0.2191  g_loss:2.5533
# epoch:613  d_loss:0.3216  g_loss:2.0510
# epoch:614  d_loss:0.2929  g_loss:2.2297
# epoch:615  d_loss:0.2166  g_loss:2.2309
# epoch:616  d_loss:0.1716  g_loss:2.1411
# epoch:617  d_loss:0.4128  g_loss:2.3478
# epoch:618  d_loss:0.3391  g_loss:2.4204
# epoch:619  d_loss:0.2164  g_loss:3.2180
# epoch:620  d_loss:0.2164  g_loss:3.3598
# epoch:621  d_loss:0.3331  g_loss:2.9860
# epoch:622  d_loss:0.3674  g_loss:2.6091
# epoch:623  d_loss:0.3383  g_loss:2.1232
# epoch:624  d_loss:0.4062  g_loss:1.9905
# epoch:625  d_loss:0.6012  g_loss:1.8437
# epoch:626  d_loss:0.5524  g_loss:1.9796
# epoch:627  d_loss:0.5415  g_loss:2.5271
# epoch:628  d_loss:0.6504  g_loss:2.4028
# epoch:629  d_loss:0.4383  g_loss:2.6108
# epoch:630  d_loss:0.5312  g_loss:2.1536
# epoch:631  d_loss:0.5887  g_loss:1.8941
# epoch:632  d_loss:0.7630  g_loss:2.3224
# epoch:633  d_loss:0.7197  g_loss:2.2646
# epoch:634  d_loss:0.9537  g_loss:2.4867
# epoch:635  d_loss:0.5445  g_loss:2.3163
# epoch:636  d_loss:0.4488  g_loss:2.6003
# epoch:637  d_loss:0.2957  g_loss:2.9831
# epoch:638  d_loss:0.4675  g_loss:3.1344
# epoch:639  d_loss:0.3327  g_loss:2.8319
# epoch:640  d_loss:0.3140  g_loss:2.6809
# epoch:641  d_loss:0.4757  g_loss:2.3799
# epoch:642  d_loss:0.2546  g_loss:2.2512
# epoch:643  d_loss:0.1782  g_loss:2.1403
# epoch:644  d_loss:0.2610  g_loss:2.2475
# epoch:645  d_loss:0.5555  g_loss:1.8183
# epoch:646  d_loss:0.4156  g_loss:2.0085
# epoch:647  d_loss:0.5884  g_loss:1.2593
# epoch:648  d_loss:0.3302  g_loss:1.8487
# epoch:649  d_loss:0.4749  g_loss:1.7861
# epoch:650  d_loss:0.3002  g_loss:2.1881
# epoch:651  d_loss:0.6024  g_loss:1.4388
# epoch:652  d_loss:0.4486  g_loss:1.5112
# epoch:653  d_loss:0.5261  g_loss:1.2698
# epoch:654  d_loss:0.4179  g_loss:1.5402
# epoch:655  d_loss:0.3045  g_loss:2.0782
# epoch:656  d_loss:0.3128  g_loss:2.7350
# epoch:657  d_loss:0.3394  g_loss:2.4763
# epoch:658  d_loss:0.2781  g_loss:2.3051
# epoch:659  d_loss:0.3073  g_loss:2.0070
# epoch:660  d_loss:0.5138  g_loss:2.0927
# epoch:661  d_loss:0.1935  g_loss:2.5497
# epoch:662  d_loss:0.2048  g_loss:2.8268
# epoch:663  d_loss:0.4020  g_loss:2.7757
# epoch:664  d_loss:0.2392  g_loss:2.7334
# epoch:665  d_loss:0.5478  g_loss:2.1955
# epoch:666  d_loss:0.3837  g_loss:2.2350
# epoch:667  d_loss:0.3165  g_loss:1.9267
# epoch:668  d_loss:0.3378  g_loss:2.0102
# epoch:669  d_loss:0.3977  g_loss:2.1332
# epoch:670  d_loss:0.4392  g_loss:1.8953
# epoch:671  d_loss:0.5000  g_loss:1.7767
# epoch:672  d_loss:0.7796  g_loss:1.3115
# epoch:673  d_loss:0.5021  g_loss:1.3700
# epoch:674  d_loss:0.6389  g_loss:1.2849
# epoch:675  d_loss:0.7804  g_loss:1.2929
# epoch:676  d_loss:1.0676  g_loss:1.0527
# epoch:677  d_loss:0.9406  g_loss:1.1041
# epoch:678  d_loss:0.7959  g_loss:1.0933
# epoch:679  d_loss:0.8455  g_loss:1.3078
# epoch:680  d_loss:0.8073  g_loss:1.5029
# epoch:681  d_loss:0.5372  g_loss:2.3489
# epoch:682  d_loss:0.5970  g_loss:2.2872
# epoch:683  d_loss:0.5531  g_loss:2.0239
# epoch:684  d_loss:0.3028  g_loss:1.9533
# epoch:685  d_loss:0.1990  g_loss:2.1939
# epoch:686  d_loss:0.2327  g_loss:2.4478
# epoch:687  d_loss:0.1918  g_loss:2.5442
# epoch:688  d_loss:0.1682  g_loss:3.0259
# epoch:689  d_loss:0.1773  g_loss:2.8295
# epoch:690  d_loss:0.1902  g_loss:2.8088
# epoch:691  d_loss:0.2017  g_loss:2.2131
# epoch:692  d_loss:0.2194  g_loss:2.2141
# epoch:693  d_loss:0.1855  g_loss:2.1138
# epoch:694  d_loss:0.3120  g_loss:2.1017
# epoch:695  d_loss:0.2834  g_loss:1.9383
# epoch:696  d_loss:0.3416  g_loss:2.2631
# epoch:697  d_loss:0.4616  g_loss:1.8888
# epoch:698  d_loss:0.4003  g_loss:1.8837
# epoch:699  d_loss:0.8364  g_loss:1.6892
# epoch:700  d_loss:0.5179  g_loss:1.4608
# epoch:701  d_loss:0.4646  g_loss:1.7934
# epoch:702  d_loss:0.6625  g_loss:1.3625
# epoch:703  d_loss:0.8299  g_loss:1.2485
# epoch:704  d_loss:0.6979  g_loss:1.1390
# epoch:705  d_loss:0.8377  g_loss:1.0534
# epoch:706  d_loss:0.9876  g_loss:0.8038
# epoch:707  d_loss:0.5332  g_loss:1.1952
# epoch:708  d_loss:0.5366  g_loss:1.6548
# epoch:709  d_loss:0.6485  g_loss:1.4844
# epoch:710  d_loss:0.6012  g_loss:1.4241
# epoch:711  d_loss:0.6663  g_loss:1.1474
# epoch:712  d_loss:0.5484  g_loss:1.1669
# epoch:713  d_loss:0.3799  g_loss:1.4406
# epoch:714  d_loss:0.4321  g_loss:1.5403
# epoch:715  d_loss:0.4915  g_loss:1.5241
# epoch:716  d_loss:0.2520  g_loss:2.3897
# epoch:717  d_loss:0.3578  g_loss:2.2250
# epoch:718  d_loss:0.3118  g_loss:2.1241
# epoch:719  d_loss:0.3271  g_loss:2.2990
# epoch:720  d_loss:0.3091  g_loss:1.7629
# epoch:721  d_loss:0.2755  g_loss:2.0327
# epoch:722  d_loss:0.4184  g_loss:2.0541
# epoch:723  d_loss:0.3529  g_loss:1.9977
# epoch:724  d_loss:0.3469  g_loss:1.8946
# epoch:725  d_loss:0.3877  g_loss:2.2654
# epoch:726  d_loss:0.3056  g_loss:2.6871
# epoch:727  d_loss:0.4313  g_loss:2.4206
# epoch:728  d_loss:0.2803  g_loss:2.3080
# epoch:729  d_loss:0.3872  g_loss:1.7078
# epoch:730  d_loss:0.5945  g_loss:1.1914
# epoch:731  d_loss:0.4717  g_loss:1.6711
# epoch:732  d_loss:0.3737  g_loss:2.0102
# epoch:733  d_loss:0.4786  g_loss:2.2222
# epoch:734  d_loss:0.3668  g_loss:2.6544
# epoch:735  d_loss:0.4077  g_loss:2.3749
# epoch:736  d_loss:0.5415  g_loss:1.6029
# epoch:737  d_loss:0.6414  g_loss:1.2530
# epoch:738  d_loss:0.6615  g_loss:1.1308
# epoch:739  d_loss:0.6690  g_loss:1.4399
# epoch:740  d_loss:0.5650  g_loss:1.7148
# epoch:741  d_loss:0.6668  g_loss:2.2298
# epoch:742  d_loss:0.8590  g_loss:1.7221
# epoch:743  d_loss:0.5873  g_loss:1.3406
# epoch:744  d_loss:0.6111  g_loss:1.3075
# epoch:745  d_loss:0.4620  g_loss:1.4591
# epoch:746  d_loss:0.5415  g_loss:1.6345
# epoch:747  d_loss:0.3712  g_loss:1.7093
# epoch:748  d_loss:0.2183  g_loss:2.3396
# epoch:749  d_loss:0.4198  g_loss:2.4880
# epoch:750  d_loss:0.4158  g_loss:2.2319
# epoch:751  d_loss:0.4156  g_loss:1.9143
# epoch:752  d_loss:0.3757  g_loss:1.6352
# epoch:753  d_loss:0.4242  g_loss:1.4298
# epoch:754  d_loss:0.2771  g_loss:2.0211
# epoch:755  d_loss:0.2643  g_loss:2.4734
# epoch:756  d_loss:0.2810  g_loss:2.3652
# epoch:757  d_loss:0.4646  g_loss:2.0986
# epoch:758  d_loss:0.4278  g_loss:1.5720
# epoch:759  d_loss:0.3743  g_loss:1.5057
# epoch:760  d_loss:0.4339  g_loss:1.3663
# epoch:761  d_loss:0.5697  g_loss:1.4521
# epoch:762  d_loss:0.4162  g_loss:2.1040
# epoch:763  d_loss:0.4491  g_loss:2.2511
# epoch:764  d_loss:0.4894  g_loss:2.0768
# epoch:765  d_loss:0.5047  g_loss:1.4650
# epoch:766  d_loss:0.3558  g_loss:1.5038
# epoch:767  d_loss:0.4414  g_loss:1.4493
# epoch:768  d_loss:0.4038  g_loss:1.4501
# epoch:769  d_loss:0.4527  g_loss:2.0036
# epoch:770  d_loss:0.5476  g_loss:1.8493
# epoch:771  d_loss:0.8065  g_loss:1.5600
# epoch:772  d_loss:0.6380  g_loss:1.5681
# epoch:773  d_loss:0.6402  g_loss:1.5986
# epoch:774  d_loss:0.6423  g_loss:1.5373
# epoch:775  d_loss:0.6250  g_loss:1.7630
# epoch:776  d_loss:0.6259  g_loss:1.2992
# epoch:777  d_loss:0.5554  g_loss:1.2483
# epoch:778  d_loss:0.5387  g_loss:1.1331
# epoch:779  d_loss:0.4888  g_loss:1.1893
# epoch:780  d_loss:0.4515  g_loss:1.4826
# epoch:781  d_loss:0.4375  g_loss:1.4812
# epoch:782  d_loss:0.5640  g_loss:1.4827
# epoch:783  d_loss:0.4643  g_loss:1.6952
# epoch:784  d_loss:0.4601  g_loss:1.5628
# epoch:785  d_loss:0.3370  g_loss:1.6111
# epoch:786  d_loss:0.4684  g_loss:1.2449
# epoch:787  d_loss:0.3740  g_loss:1.8812
# epoch:788  d_loss:0.4415  g_loss:1.8132
# epoch:789  d_loss:0.2934  g_loss:1.8864
# epoch:790  d_loss:0.3755  g_loss:2.3839
# epoch:791  d_loss:0.3802  g_loss:2.2992
# epoch:792  d_loss:0.2504  g_loss:2.2723
# epoch:793  d_loss:0.4018  g_loss:1.9378
# epoch:794  d_loss:0.2662  g_loss:2.0078
# epoch:795  d_loss:0.2875  g_loss:1.9956
# epoch:796  d_loss:0.3791  g_loss:1.9784
# epoch:797  d_loss:0.3098  g_loss:1.9365
# epoch:798  d_loss:0.2735  g_loss:2.3125
# epoch:799  d_loss:0.2247  g_loss:2.7846
# epoch:800  d_loss:0.3298  g_loss:2.2062
# epoch:801  d_loss:0.2894  g_loss:2.0067
# epoch:802  d_loss:0.4814  g_loss:1.6479
# epoch:803  d_loss:0.4536  g_loss:1.9832
# epoch:804  d_loss:0.3791  g_loss:2.4253
# epoch:805  d_loss:0.5776  g_loss:2.1087
# epoch:806  d_loss:0.5339  g_loss:2.2544
# epoch:807  d_loss:0.4128  g_loss:1.8349
# epoch:808  d_loss:0.5209  g_loss:1.4052
# epoch:809  d_loss:0.5592  g_loss:1.8980
# epoch:810  d_loss:0.5336  g_loss:1.6750
# epoch:811  d_loss:0.6404  g_loss:1.9071
# epoch:812  d_loss:0.6848  g_loss:1.6961
# epoch:813  d_loss:0.5687  g_loss:1.4651
# epoch:814  d_loss:0.6161  g_loss:1.2747
# epoch:815  d_loss:0.6751  g_loss:1.4227
# epoch:816  d_loss:0.5181  g_loss:1.8526
# epoch:817  d_loss:0.3872  g_loss:1.8631
# epoch:818  d_loss:0.4359  g_loss:2.1548
# epoch:819  d_loss:0.5572  g_loss:1.9283
# epoch:820  d_loss:0.4831  g_loss:1.4516
# epoch:821  d_loss:0.4797  g_loss:1.4665
# epoch:822  d_loss:0.4428  g_loss:1.4166
# epoch:823  d_loss:0.5540  g_loss:1.5976
# epoch:824  d_loss:0.4037  g_loss:2.0264
# epoch:825  d_loss:0.3334  g_loss:2.1953
# epoch:826  d_loss:0.4201  g_loss:2.1403
# epoch:827  d_loss:0.3934  g_loss:2.0322
# epoch:828  d_loss:0.3816  g_loss:2.2354
# epoch:829  d_loss:0.3955  g_loss:1.9635
# epoch:830  d_loss:0.2738  g_loss:2.5491
# epoch:831  d_loss:0.4094  g_loss:2.4196
# epoch:832  d_loss:0.2975  g_loss:2.4669
# epoch:833  d_loss:0.2346  g_loss:2.3608
# epoch:834  d_loss:0.1718  g_loss:2.3587
# epoch:835  d_loss:0.2839  g_loss:2.2263
# epoch:836  d_loss:0.3116  g_loss:2.4130
# epoch:837  d_loss:0.3019  g_loss:2.3782
# epoch:838  d_loss:0.2326  g_loss:2.4842
# epoch:839  d_loss:0.3303  g_loss:2.1629
# epoch:840  d_loss:0.2510  g_loss:2.4488
# epoch:841  d_loss:0.3211  g_loss:2.2887
# epoch:842  d_loss:0.3348  g_loss:2.0134
# epoch:843  d_loss:0.3606  g_loss:1.9648
# epoch:844  d_loss:0.6329  g_loss:1.8385
# epoch:845  d_loss:0.3072  g_loss:1.8064
# epoch:846  d_loss:0.3489  g_loss:1.8125
# epoch:847  d_loss:0.5327  g_loss:2.2440
# epoch:848  d_loss:0.3406  g_loss:2.6870
# epoch:849  d_loss:0.4405  g_loss:2.0973
# epoch:850  d_loss:0.3752  g_loss:1.8028
# epoch:851  d_loss:0.5944  g_loss:1.7796
# epoch:852  d_loss:0.6131  g_loss:1.4606
# epoch:853  d_loss:0.5779  g_loss:1.9017
# epoch:854  d_loss:0.5168  g_loss:1.9280
# epoch:855  d_loss:0.6167  g_loss:1.3523
# epoch:856  d_loss:0.6550  g_loss:1.6458
